# %% [markdown]
# ##                              POWER BI DASHBOARD CAPSTONE PROJECT

# %% [markdown]
# ### BUSINESS UNDERSTANDING
#
# You are assigned a client by getINNOtized to design and deliver an end-to-end business  intelligence solution. Your client has collected transactional data for the year 2019 but hasn’t been able to  put it to good use. The client hopes you can analyze the data and put together a report  to help them find opportunities to drive more sales and work more efficiently.
#
# ## Hypothesis
#
# Null Hypothesis: The dataset is not stationary
#
# Alternative Hypothesis: The dataset is stationary
#
#
# ## Technical Questions:
#
# 1. How much money did we make this year?
#
# 2. Can we identify any seasonality in the  sales?
#
# 3. What are our best and worst-selling products?
#
# 4. How do sales compare to previous months or weeks?
#
# 5. Which cities are our products delivered to most?
#
# 6. How do product categories compare in revenue generated and quantities  ordered?
#
# 7. You are required to show additional details from your findings in your data.
#
# NB: Products with unit prices above $99.99 should be labelled high-level products  otherwise they should be basic level.

# %%
# Importing Libraries

#!pip install pyodbc

import pyodbc #just installed with pip 

from dotenv import dotenv_values 

#import os

import pandas as pd 
import numpy as np

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## DATASETS
#
# ### The first 6 datasets was downloaded from one drive location provided.
#
# ### The second 6 datasets from a remote database.

# %% [markdown]
# ## LOADING ALL THE 12 DATASETS AFTER DOWNLOADING THEM

# %%
# Loading all the dataset from January to December 2019

Jan_sales = pd.read_csv("datasets\Sales_January_2019.csv")

Feb_sales = pd.read_csv("datasets\Sales_February_2019.csv")

March_sales = pd.read_csv("datasets\Sales_March_2019.csv")

Apr_sales = pd.read_csv("datasets\Sales_April_2019.csv")

May_sales = pd.read_csv("datasets\Sales_May_2019.csv")

Jun_sales = pd.read_csv("datasets\Sales_June_2019.csv")

Jul_sales = pd.read_csv("datasets\Sales_July_2019.csv")

Aug_sales = pd.read_csv("datasets\Sales_August_2019.csv")

Sept_sales = pd.read_csv("datasets\Sales_September_2019.csv")

Oct_sales = pd.read_csv("datasets\Sales_October_2019.csv")

Nov_sales = pd.read_csv("datasets\Sales_November_2019.csv")

Dec_sales = pd.read_csv("datasets\Sales_December_2019.csv")

# %%
Jan_sales
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1     01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2     01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3     01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4     01/25/19 11:59          387 10th St, Austin, TX 73301
# ...              ...                                    ...
# 9718  01/26/19 19:09            95 8th St, Dallas, TX 75001
# 9719  01/10/19 22:58    403 7th St, San Francisco, CA 94016
# 9720  01/21/19 14:31        214 Main St, Portland, OR 97035
# 9721  01/15/19 14:21      810 2nd St, Los Angeles, CA 90001
# 9722  01/13/19 16:43         428 Cedar St, Boston, MA 02215
#
# [9723 rows x 6 columns]

# %%
Dec_sales
# Out:
#        Unnamed: 0  Order_ID                     Product  Quantity_Ordered  \
# 0               0  278797.0            Wired Headphones               1.0
# 1               1  278798.0        USB-C Charging Cable               2.0
# 2               2  278799.0    Apple Airpods Headphones               1.0
# 3               3  278800.0            27in FHD Monitor               1.0
# 4               4  278801.0  Bose SoundSport Headphones               1.0
# ...           ...       ...                         ...               ...
# 17656       17656  295660.0      AAA Batteries (4-pack)               2.0
# 17657       17657  295661.0        USB-C Charging Cable               1.0
# 17658       17658  295662.0    Lightning Charging Cable               1.0
# 17659       17659  295663.0      AAA Batteries (4-pack)               1.0
# 17660       17660  295664.0                Google Phone               1.0
#
#        Price_Each                   Order_Date  \
# 0       11.990000  2021-11-19 09:54:00.0000000
# 1       11.950000  2017-11-19 10:03:00.0000000
# 2      150.000000  2019-11-19 14:56:00.0000000
# 3      149.990005  2025-11-19 22:24:00.0000000
# 4       99.989998  2009-11-19 13:56:00.0000000
# ...           ...                          ...
# 17656    2.990000  2004-11-19 14:17:00.0000000
# 17657   11.950000  2023-11-19 07:22:00.0000000
# 17658   14.950000  2013-11-19 16:12:00.0000000
# 17659    2.990000  2017-11-19 17:08:00.0000000
# 17660  600.000000  2017-11-19 16:13:00.0000000
#
#                            Purchase_Address
# 0       46 Park St, New York City, NY 10001
# 1          962 Hickory St, Austin, TX 73301
# 2      464 Cherry St, Los Angeles, CA 90001
# 3            649 10th St, Seattle, WA 98101
# 4             522 Hill St, Boston, MA 02215
# ...                                     ...
# 17656     574 4th St, Los Angeles, CA 90001
# 17657          359 1st St, Austin, TX 73301
# 17658         900 10th St, Boston, MA 02215
# 17659       592 Sunset St, Boston, MA 02215
# 17660      428 Jackson St, Boston, MA 02215
#
# [17661 rows x 7 columns]

# %%
# Joining the datasets from January to June as dataset1

dataset1 = pd.concat([Jan_sales, Feb_sales, March_sales,Apr_sales,May_sales,Jun_sales])

# %%
dataset1
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 13617   222905    AAA Batteries (4-pack)                1       2.99
# 13618   222906          27in FHD Monitor                1     149.99
# 13619   222907      USB-C Charging Cable                1      11.95
# 13620   222908      USB-C Charging Cable                1      11.95
# 13621   222909    AAA Batteries (4-pack)                1       2.99
#
#            Order Date                       Purchase Address
# 0      01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1      01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2      01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3      01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4      01/25/19 11:59          387 10th St, Austin, TX 73301
# ...               ...                                    ...
# 13617  06/07/19 19:02          795 Pine St, Boston, MA 02215
# 13618  06/01/19 19:29  495 North St, New York City, NY 10001
# 13619  06/22/19 18:57  319 Ridge St, San Francisco, CA 94016
# 13620  06/26/19 18:35   916 Main St, San Francisco, CA 94016
# 13621  06/25/19 14:33         209 11th St, Atlanta, GA 30301
#
# [85625 rows x 6 columns]

# %%
# concatinating datasets from July to December as dataset2

dataset2 = pd.concat([Jul_sales,Aug_sales,Sept_sales,Oct_sales,Nov_sales,Dec_sales])

# %%
dataset2
# Out:
#        Unnamed: 0  Order_ID                   Product  Quantity_Ordered  \
# 0               0  222910.0  Apple Airpods Headphones               1.0
# 1               1  222911.0             Flatscreen TV               1.0
# 2               2  222912.0     AA Batteries (4-pack)               1.0
# 3               3  222913.0     AA Batteries (4-pack)               1.0
# 4               4  222914.0    AAA Batteries (4-pack)               5.0
# ...           ...       ...                       ...               ...
# 17656       17656  295660.0    AAA Batteries (4-pack)               2.0
# 17657       17657  295661.0      USB-C Charging Cable               1.0
# 17658       17658  295662.0  Lightning Charging Cable               1.0
# 17659       17659  295663.0    AAA Batteries (4-pack)               1.0
# 17660       17660  295664.0              Google Phone               1.0
#
#        Price_Each                   Order_Date  \
# 0          150.00  2026-07-19 16:51:00.0000000
# 1          300.00  2005-07-19 08:55:00.0000000
# 2            3.84  2029-07-19 12:41:00.0000000
# 3            3.84  2028-07-19 10:15:00.0000000
# 4            2.99  2031-07-19 02:13:00.0000000
# ...           ...                          ...
# 17656        2.99  2004-11-19 14:17:00.0000000
# 17657       11.95  2023-11-19 07:22:00.0000000
# 17658       14.95  2013-11-19 16:12:00.0000000
# 17659        2.99  2017-11-19 17:08:00.0000000
# 17660      600.00  2017-11-19 16:13:00.0000000
#
#                         Purchase_Address
# 0        389 South St, Atlanta, GA 30301
# 1          590 4th St, Seattle, WA 98101
# 2         861 Hill St, Atlanta, GA 30301
# 3        190 Ridge St, Atlanta, GA 30301
# 4       824 Forest St, Seattle, WA 98101
# ...                                  ...
# 17656  574 4th St, Los Angeles, CA 90001
# 17657       359 1st St, Austin, TX 73301
# 17658      900 10th St, Boston, MA 02215
# 17659    592 Sunset St, Boston, MA 02215
# 17660   428 Jackson St, Boston, MA 02215
#
# [93769 rows x 7 columns]

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA)

# %%
# Analysing dataset1

dataset1.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
dataset2.head()
# Out:
#    Unnamed: 0  Order_ID                   Product  Quantity_Ordered  \
# 0           0  222910.0  Apple Airpods Headphones               1.0
# 1           1  222911.0             Flatscreen TV               1.0
# 2           2  222912.0     AA Batteries (4-pack)               1.0
# 3           3  222913.0     AA Batteries (4-pack)               1.0
# 4           4  222914.0    AAA Batteries (4-pack)               5.0
#
#    Price_Each                   Order_Date                  Purchase_Address
# 0      150.00  2026-07-19 16:51:00.0000000   389 South St, Atlanta, GA 30301
# 1      300.00  2005-07-19 08:55:00.0000000     590 4th St, Seattle, WA 98101
# 2        3.84  2029-07-19 12:41:00.0000000    861 Hill St, Atlanta, GA 30301
# 3        3.84  2028-07-19 10:15:00.0000000   190 Ridge St, Atlanta, GA 30301
# 4        2.99  2031-07-19 02:13:00.0000000  824 Forest St, Seattle, WA 98101

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85625 entries, 0 to 13621
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          85380 non-null  object
#  1   Product           85380 non-null  object
#  2   Quantity Ordered  85380 non-null  object
#  3   Price Each        85380 non-null  object
#  4   Order Date        85380 non-null  object
#  5   Purchase Address  85380 non-null  object
# dtypes: object(6)
# memory usage: 4.6+ MB

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93769 entries, 0 to 17660
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        93769 non-null  int64
#  1   Order_ID          93321 non-null  float64
#  2   Product           93504 non-null  object
#  3   Quantity_Ordered  93321 non-null  float64
#  4   Price_Each        93321 non-null  float64
#  5   Order_Date        93321 non-null  object
#  6   Purchase_Address  93504 non-null  object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 5.7+ MB

# %%
dataset1.shape
# Out:
# (85625, 6)

# %%
dataset2.shape
# Out:
# (93769, 7)

# %%
dataset1.isnull().sum()
# Out:
# Order ID            245
# Product             245
# Quantity Ordered    245
# Price Each          245
# Order Date          245
# Purchase Address    245
# dtype: int64

# %%
dataset2.isnull().sum()
# Out:
# Unnamed: 0            0
# Order_ID            448
# Product             265
# Quantity_Ordered    448
# Price_Each          448
# Order_Date          448
# Purchase_Address    265
# dtype: int64

# %% [markdown]
# ## FILLING MISSING VALUES WITH FORWARD AND BACKWARD FILL

# %%
# Using forward and Backward fill

dataset1 = dataset1.ffill().bfill()

dataset2 = dataset2.ffill().bfill()

# %%
dataset1.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
dataset2.isnull().sum()
# Out:
# Unnamed: 0          0
# Order_ID            0
# Product             0
# Quantity_Ordered    0
# Price_Each          0
# Order_Date          0
# Purchase_Address    0
# dtype: int64

# %%
# CONVERT ORDERED DATE TO DAYTIME

dataset1['Order Date'] = pd.to_datetime(dataset1['Order Date'], dayfirst=True, errors='coerce')

dataset2['Order_Date'] = pd.to_datetime(dataset2['Order_Date'])

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
# remove the unwanted column "unnamed" in dataset2

dataset2.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# rename all the columns in dataset2 to be same with dataset1 columns

dataset2 = dataset2.rename(columns = {'Order ID': 'Order_ID', 'Quantity Ordered': 'Quantity_Ordered', 
                                      'Price_Each':'Unit_Price ($)','Order_Date':'Date',
                                     'Purchase Address':'Purchase_Address'})

# %%
dataset1.columns = dataset1.columns.str.replace('Price Each', 'Unit_Price ($)')

dataset1.columns = dataset1.columns.str.replace('Order Date', 'Date')

dataset1.columns = dataset1.columns.str.replace('Quantity Ordered', 'Quantity_Ordered')

dataset1.columns = dataset1.columns.str.replace('Purchase Address', 'Purchase_Address')

dataset1.columns = dataset1.columns.str.replace('Order ID', 'Order_ID')

# %%
dataset1
# Out:
#       Order_ID                   Product Quantity_Ordered Unit_Price ($)  \
# 0       141234                    iPhone                1            700
# 1       141235  Lightning Charging Cable                1          14.95
# 2       141236          Wired Headphones                2          11.99
# 3       141237          27in FHD Monitor                1         149.99
# 4       141238          Wired Headphones                1          11.99
# ...        ...                       ...              ...            ...
# 13617   222905    AAA Batteries (4-pack)                1           2.99
# 13618   222906          27in FHD Monitor                1         149.99
# 13619   222907      USB-C Charging Cable                1          11.95
# 13620   222908      USB-C Charging Cable                1          11.95
# 13621   222909    AAA Batteries (4-pack)                1           2.99
#
#                      Date                       Purchase_Address
# 0     2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215
# 1     2019-01-28 14:15:00       185 Maple St, Portland, OR 97035
# 2     2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016
# 3     2019-05-01 20:33:00     738 10th St, Los Angeles, CA 90001
# 4     2019-01-25 11:59:00          387 10th St, Austin, TX 73301
# ...                   ...                                    ...
# 13617 2019-07-06 19:02:00          795 Pine St, Boston, MA 02215
# 13618 2019-01-06 19:29:00  495 North St, New York City, NY 10001
# 13619 2019-06-22 18:57:00  319 Ridge St, San Francisco, CA 94016
# 13620 2019-06-26 18:35:00   916 Main St, San Francisco, CA 94016
# 13621 2019-06-25 14:33:00         209 11th St, Atlanta, GA 30301
#
# [85625 rows x 6 columns]

# %%
dataset2
# Out:
#        Order_ID                   Product  Quantity_Ordered  Unit_Price ($)  \
# 0      222910.0  Apple Airpods Headphones               1.0          150.00
# 1      222911.0             Flatscreen TV               1.0          300.00
# 2      222912.0     AA Batteries (4-pack)               1.0            3.84
# 3      222913.0     AA Batteries (4-pack)               1.0            3.84
# 4      222914.0    AAA Batteries (4-pack)               5.0            2.99
# ...         ...                       ...               ...             ...
# 17656  295660.0    AAA Batteries (4-pack)               2.0            2.99
# 17657  295661.0      USB-C Charging Cable               1.0           11.95
# 17658  295662.0  Lightning Charging Cable               1.0           14.95
# 17659  295663.0    AAA Batteries (4-pack)               1.0            2.99
# 17660  295664.0              Google Phone               1.0          600.00
#
#                      Date                   Purchase_Address
# 0     2026-07-19 16:51:00    389 South St, Atlanta, GA 30301
# 1     2005-07-19 08:55:00      590 4th St, Seattle, WA 98101
# 2     2029-07-19 12:41:00     861 Hill St, Atlanta, GA 30301
# 3     2028-07-19 10:15:00    190 Ridge St, Atlanta, GA 30301
# 4     2031-07-19 02:13:00   824 Forest St, Seattle, WA 98101
# ...                   ...                                ...
# 17656 2004-11-19 14:17:00  574 4th St, Los Angeles, CA 90001
# 17657 2023-11-19 07:22:00       359 1st St, Austin, TX 73301
# 17658 2013-11-19 16:12:00      900 10th St, Boston, MA 02215
# 17659 2017-11-19 17:08:00    592 Sunset St, Boston, MA 02215
# 17660 2017-11-19 16:13:00   428 Jackson St, Boston, MA 02215
#
# [93769 rows x 6 columns]

# %% [markdown]
# ### CONCATINATING THE TWO DATASETS

# %%
# MERGING Dataset1 and Dataset2

cleaned_data = pd.concat([dataset1, dataset2])

# %%
cleaned_data
# Out:
#        Order_ID                   Product Quantity_Ordered Unit_Price ($)  \
# 0        141234                    iPhone                1            700
# 1        141235  Lightning Charging Cable                1          14.95
# 2        141236          Wired Headphones                2          11.99
# 3        141237          27in FHD Monitor                1         149.99
# 4        141238          Wired Headphones                1          11.99
# ...         ...                       ...              ...            ...
# 17656  295660.0    AAA Batteries (4-pack)              2.0           2.99
# 17657  295661.0      USB-C Charging Cable              1.0          11.95
# 17658  295662.0  Lightning Charging Cable              1.0          14.95
# 17659  295663.0    AAA Batteries (4-pack)              1.0           2.99
# 17660  295664.0              Google Phone              1.0          600.0
#
#                      Date                       Purchase_Address
# 0     2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215
# 1     2019-01-28 14:15:00       185 Maple St, Portland, OR 97035
# 2     2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016
# 3     2019-05-01 20:33:00     738 10th St, Los Angeles, CA 90001
# 4     2019-01-25 11:59:00          387 10th St, Austin, TX 73301
# ...                   ...                                    ...
# 17656 2004-11-19 14:17:00      574 4th St, Los Angeles, CA 90001
# 17657 2023-11-19 07:22:00           359 1st St, Austin, TX 73301
# 17658 2013-11-19 16:12:00          900 10th St, Boston, MA 02215
# 17659 2017-11-19 17:08:00        592 Sunset St, Boston, MA 02215
# 17660 2017-11-19 16:13:00       428 Jackson St, Boston, MA 02215
#
# [179394 rows x 6 columns]

# %%
# Setting the Date column to be index

cleaded_data = cleaned_data.set_index('Date')

cleaned_data
# Out:
#        Order_ID                   Product Quantity_Ordered Unit_Price ($)  \
# 0        141234                    iPhone                1            700
# 1        141235  Lightning Charging Cable                1          14.95
# 2        141236          Wired Headphones                2          11.99
# 3        141237          27in FHD Monitor                1         149.99
# 4        141238          Wired Headphones                1          11.99
# ...         ...                       ...              ...            ...
# 17656  295660.0    AAA Batteries (4-pack)              2.0           2.99
# 17657  295661.0      USB-C Charging Cable              1.0          11.95
# 17658  295662.0  Lightning Charging Cable              1.0          14.95
# 17659  295663.0    AAA Batteries (4-pack)              1.0           2.99
# 17660  295664.0              Google Phone              1.0          600.0
#
#                      Date                       Purchase_Address
# 0     2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215
# 1     2019-01-28 14:15:00       185 Maple St, Portland, OR 97035
# 2     2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016
# 3     2019-05-01 20:33:00     738 10th St, Los Angeles, CA 90001
# 4     2019-01-25 11:59:00          387 10th St, Austin, TX 73301
# ...                   ...                                    ...
# 17656 2004-11-19 14:17:00      574 4th St, Los Angeles, CA 90001
# 17657 2023-11-19 07:22:00           359 1st St, Austin, TX 73301
# 17658 2013-11-19 16:12:00          900 10th St, Boston, MA 02215
# 17659 2017-11-19 17:08:00        592 Sunset St, Boston, MA 02215
# 17660 2017-11-19 16:13:00       428 Jackson St, Boston, MA 02215
#
# [179394 rows x 6 columns]

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179394 entries, 0 to 17660
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          179394 non-null  object
#  1   Product           179394 non-null  object
#  2   Quantity_Ordered  179394 non-null  object
#  3   Unit_Price ($)    179394 non-null  object
#  4   Date              179234 non-null  datetime64[ns]
#  5   Purchase_Address  179394 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 9.6+ MB

# %%
# formating the QuantityOrdered Column to maintain one decimal places

cleaned_data['Quantity_Ordered'] = cleaned_data['Quantity_Ordered'].apply(str)

cleaned_data["Quantity_Ordered"] = cleaned_data["Quantity_Ordered"].str.split(".").str[0]

# converting to float datatype

cleaned_data['Quantity_Ordered'] = pd.to_numeric(cleaned_data['Quantity_Ordered'], errors='coerce')

cleaned_data['Unit_Price ($)'] = pd.to_numeric(cleaned_data['Unit_Price ($)'], errors='coerce')

# %%
cleaned_data
# Out:
#        Order_ID                   Product  Quantity_Ordered  Unit_Price ($)  \
# 0        141234                    iPhone               1.0          700.00
# 1        141235  Lightning Charging Cable               1.0           14.95
# 2        141236          Wired Headphones               2.0           11.99
# 3        141237          27in FHD Monitor               1.0          149.99
# 4        141238          Wired Headphones               1.0           11.99
# ...         ...                       ...               ...             ...
# 17656  295660.0    AAA Batteries (4-pack)               2.0            2.99
# 17657  295661.0      USB-C Charging Cable               1.0           11.95
# 17658  295662.0  Lightning Charging Cable               1.0           14.95
# 17659  295663.0    AAA Batteries (4-pack)               1.0            2.99
# 17660  295664.0              Google Phone               1.0          600.00
#
#                      Date                       Purchase_Address
# 0     2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215
# 1     2019-01-28 14:15:00       185 Maple St, Portland, OR 97035
# 2     2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016
# 3     2019-05-01 20:33:00     738 10th St, Los Angeles, CA 90001
# 4     2019-01-25 11:59:00          387 10th St, Austin, TX 73301
# ...                   ...                                    ...
# 17656 2004-11-19 14:17:00      574 4th St, Los Angeles, CA 90001
# 17657 2023-11-19 07:22:00           359 1st St, Austin, TX 73301
# 17658 2013-11-19 16:12:00          900 10th St, Boston, MA 02215
# 17659 2017-11-19 17:08:00        592 Sunset St, Boston, MA 02215
# 17660 2017-11-19 16:13:00       428 Jackson St, Boston, MA 02215
#
# [179394 rows x 6 columns]

# %%
# set date column as index

cleaned_data.set_index((cleaned_data.select_dtypes(include=[np.datetime64]).columns).tolist())
# Out:
#                      Order_ID                   Product  Quantity_Ordered  \
# Date
# 2019-01-22 21:25:00    141234                    iPhone               1.0
# 2019-01-28 14:15:00    141235  Lightning Charging Cable               1.0
# 2019-01-17 13:33:00    141236          Wired Headphones               2.0
# 2019-05-01 20:33:00    141237          27in FHD Monitor               1.0
# 2019-01-25 11:59:00    141238          Wired Headphones               1.0
# ...                       ...                       ...               ...
# 2004-11-19 14:17:00  295660.0    AAA Batteries (4-pack)               2.0
# 2023-11-19 07:22:00  295661.0      USB-C Charging Cable               1.0
# 2013-11-19 16:12:00  295662.0  Lightning Charging Cable               1.0
# 2017-11-19 17:08:00  295663.0    AAA Batteries (4-pack)               1.0
# 2017-11-19 16:13:00  295664.0              Google Phone               1.0
#
#                      Unit_Price ($)                       Purchase_Address
# Date
# 2019-01-22 21:25:00          700.00        944 Walnut St, Boston, MA 02215
# 2019-01-28 14:15:00           14.95       185 Maple St, Portland, OR 97035
# 2019-01-17 13:33:00           11.99  538 Adams St, San Francisco, CA 94016
# 2019-05-01 20:33:00          149.99     738 10th St, Los Angeles, CA 90001
# 2019-01-25 11:59:00           11.99          387 10th St, Austin, TX 73301
# ...                             ...                                    ...
# 2004-11-19 14:17:00            2.99      574 4th St, Los Angeles, CA 90001
# 2023-11-19 07:22:00           11.95           359 1st St, Austin, TX 73301
# 2013-11-19 16:12:00           14.95          900 10th St, Boston, MA 02215
# 2017-11-19 17:08:00            2.99        592 Sunset St, Boston, MA 02215
# 2017-11-19 16:13:00          600.00       428 Jackson St, Boston, MA 02215
#
# [179394 rows x 5 columns]

# %%
# Create new columns 'Year, month and week'

cleaned_data['Week'] = cleaned_data['Date'].dt.week

cleaned_data['Month'] = cleaned_data['Date'].dt.month

cleaned_data['Year'] = cleaned_data['Date'].dt.year

# %%
cleaned_data
# Out:
#        Order_ID                   Product  Quantity_Ordered  Unit_Price ($)  \
# 0        141234                    iPhone               1.0          700.00
# 1        141235  Lightning Charging Cable               1.0           14.95
# 2        141236          Wired Headphones               2.0           11.99
# 3        141237          27in FHD Monitor               1.0          149.99
# 4        141238          Wired Headphones               1.0           11.99
# ...         ...                       ...               ...             ...
# 17656  295660.0    AAA Batteries (4-pack)               2.0            2.99
# 17657  295661.0      USB-C Charging Cable               1.0           11.95
# 17658  295662.0  Lightning Charging Cable               1.0           14.95
# 17659  295663.0    AAA Batteries (4-pack)               1.0            2.99
# 17660  295664.0              Google Phone               1.0          600.00
#
#                      Date                       Purchase_Address  Week  Month  \
# 0     2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215   4.0    1.0
# 1     2019-01-28 14:15:00       185 Maple St, Portland, OR 97035   5.0    1.0
# 2     2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016   3.0    1.0
# 3     2019-05-01 20:33:00     738 10th St, Los Angeles, CA 90001  18.0    5.0
# 4     2019-01-25 11:59:00          387 10th St, Austin, TX 73301   4.0    1.0
# ...                   ...                                    ...   ...    ...
# 17656 2004-11-19 14:17:00      574 4th St, Los Angeles, CA 90001  47.0   11.0
# 17657 2023-11-19 07:22:00           359 1st St, Austin, TX 73301  46.0   11.0
# 17658 2013-11-19 16:12:00          900 10th St, Boston, MA 02215  47.0   11.0
# 17659 2017-11-19 17:08:00        592 Sunset St, Boston, MA 02215  46.0   11.0
# 17660 2017-11-19 16:13:00       428 Jackson St, Boston, MA 02215  46.0   11.0
#
#          Year
# 0      2019.0
# 1      2019.0
# 2      2019.0
# 3      2019.0
# 4      2019.0
# ...       ...
# 17656  2004.0
# 17657  2023.0
# 17658  2013.0
# 17659  2017.0
# 17660  2017.0
#
# [179394 rows x 9 columns]

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179394 entries, 0 to 17660
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          179394 non-null  object
#  1   Product           179394 non-null  object
#  2   Quantity_Ordered  179234 non-null  float64
#  3   Unit_Price ($)    179234 non-null  float64
#  4   Date              179234 non-null  datetime64[ns]
#  5   Purchase_Address  179394 non-null  object
#  6   Week              179234 non-null  float64
#  7   Month             179234 non-null  float64
#  8   Year              179234 non-null  float64
# dtypes: datetime64[ns](1), float64(5), object(3)
# memory usage: 13.7+ MB

# %%
# checking for missing values 

cleaned_data.isnull().sum()
# Out:
# Order_ID              0
# Product               0
# Quantity_Ordered    160
# Unit_Price ($)      160
# Date                160
# Purchase_Address      0
# Week                160
# Month               160
# Year                160
# dtype: int64

# %%
# Remove all NaN values in any rows

cleaned_data = cleaned_data[~cleaned_data.isna().any(axis=1)]

# %%
cleaned_data.isnull().sum()
# Out:
# Order_ID            0
# Product             0
# Quantity_Ordered    0
# Unit_Price ($)      0
# Date                0
# Purchase_Address    0
# Week                0
# Month               0
# Year                0
# dtype: int64

# %%
# Removing the decimals in Quantity_Ordered, Week, Month and Year Columns

cleaned_data['Quantity_Ordered'] = cleaned_data['Quantity_Ordered'].astype(str).apply(lambda x: x.replace('.0',''))

cleaned_data['Week'] = cleaned_data['Week'].astype(str).apply(lambda x: x.replace('.0',''))

cleaned_data['Month'] = cleaned_data['Month'].astype(str).apply(lambda x: x.replace('.0',''))

cleaned_data['Year'] = cleaned_data['Year'].astype(str).apply(lambda x: x.replace('.0',''))

# %%
cleaned_data
# Out:
#        Order_ID                   Product Quantity_Ordered  Unit_Price ($)  \
# 0        141234                    iPhone                1          700.00
# 1        141235  Lightning Charging Cable                1           14.95
# 2        141236          Wired Headphones                2           11.99
# 3        141237          27in FHD Monitor                1          149.99
# 4        141238          Wired Headphones                1           11.99
# ...         ...                       ...              ...             ...
# 17656  295660.0    AAA Batteries (4-pack)                2            2.99
# 17657  295661.0      USB-C Charging Cable                1           11.95
# 17658  295662.0  Lightning Charging Cable                1           14.95
# 17659  295663.0    AAA Batteries (4-pack)                1            2.99
# 17660  295664.0              Google Phone                1          600.00
#
#                      Date                       Purchase_Address Week Month  \
# 0     2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215    4     1
# 1     2019-01-28 14:15:00       185 Maple St, Portland, OR 97035    5     1
# 2     2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016    3     1
# 3     2019-05-01 20:33:00     738 10th St, Los Angeles, CA 90001   18     5
# 4     2019-01-25 11:59:00          387 10th St, Austin, TX 73301    4     1
# ...                   ...                                    ...  ...   ...
# 17656 2004-11-19 14:17:00      574 4th St, Los Angeles, CA 90001   47    11
# 17657 2023-11-19 07:22:00           359 1st St, Austin, TX 73301   46    11
# 17658 2013-11-19 16:12:00          900 10th St, Boston, MA 02215   47    11
# 17659 2017-11-19 17:08:00        592 Sunset St, Boston, MA 02215   46    11
# 17660 2017-11-19 16:13:00       428 Jackson St, Boston, MA 02215   46    11
#
#        Year
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
# ...     ...
# 17656  2004
# 17657  2023
# 17658  2013
# 17659  2017
# 17660  2017
#
# [179234 rows x 9 columns]

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179234 entries, 0 to 17660
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          179234 non-null  object
#  1   Product           179234 non-null  object
#  2   Quantity_Ordered  179234 non-null  object
#  3   Unit_Price ($)    179234 non-null  float64
#  4   Date              179234 non-null  datetime64[ns]
#  5   Purchase_Address  179234 non-null  object
#  6   Week              179234 non-null  object
#  7   Month             179234 non-null  object
#  8   Year              179234 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 13.7+ MB

# %%
#  converting Quantity_Ordered, Order_ID datatype to Int

cleaned_data[['Quantity_Ordered', 'Order_ID']] = cleaned_data[['Quantity_Ordered', 'Order_ID']].astype('int')

# %%
# Creating Total Amount Column

cleaned_data['Total_Amount ($)'] = cleaned_data['Quantity_Ordered']*cleaned_data['Unit_Price ($)']

# %%
cleaned_data
# Out:
#        Order_ID                   Product  Quantity_Ordered  Unit_Price ($)  \
# 0        141234                    iPhone                 1          700.00
# 1        141235  Lightning Charging Cable                 1           14.95
# 2        141236          Wired Headphones                 2           11.99
# 3        141237          27in FHD Monitor                 1          149.99
# 4        141238          Wired Headphones                 1           11.99
# ...         ...                       ...               ...             ...
# 17656    295660    AAA Batteries (4-pack)                 2            2.99
# 17657    295661      USB-C Charging Cable                 1           11.95
# 17658    295662  Lightning Charging Cable                 1           14.95
# 17659    295663    AAA Batteries (4-pack)                 1            2.99
# 17660    295664              Google Phone                 1          600.00
#
#                      Date                       Purchase_Address Week Month  \
# 0     2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215    4     1
# 1     2019-01-28 14:15:00       185 Maple St, Portland, OR 97035    5     1
# 2     2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016    3     1
# 3     2019-05-01 20:33:00     738 10th St, Los Angeles, CA 90001   18     5
# 4     2019-01-25 11:59:00          387 10th St, Austin, TX 73301    4     1
# ...                   ...                                    ...  ...   ...
# 17656 2004-11-19 14:17:00      574 4th St, Los Angeles, CA 90001   47    11
# 17657 2023-11-19 07:22:00           359 1st St, Austin, TX 73301   46    11
# 17658 2013-11-19 16:12:00          900 10th St, Boston, MA 02215   47    11
# 17659 2017-11-19 17:08:00        592 Sunset St, Boston, MA 02215   46    11
# 17660 2017-11-19 16:13:00       428 Jackson St, Boston, MA 02215   46    11
#
#        Year  Total_Amount  Total_Amount ($)
# 0      2019        700.00            700.00
# 1      2019         14.95             14.95
# 2      2019         23.98             23.98
# 3      2019        149.99            149.99
# 4      2019         11.99             11.99
# ...     ...           ...               ...
# 17656  2004          5.98              5.98
# 17657  2023         11.95             11.95
# 17658  2013         14.95             14.95
# 17659  2017          2.99              2.99
# 17660  2017        600.00            600.00
#
# [179234 rows x 11 columns]

# %%
# Fetching data for only 2019

data_2019 = cleaned_data[cleaned_data.Date.dt.year == 2019]

data_2019
# Out:
#        Order_ID                   Product  Quantity_Ordered  Unit_Price ($)  \
# 0        141234                    iPhone                 1          700.00
# 1        141235  Lightning Charging Cable                 1           14.95
# 2        141236          Wired Headphones                 2           11.99
# 3        141237          27in FHD Monitor                 1          149.99
# 4        141238          Wired Headphones                 1           11.99
# ...         ...                       ...               ...             ...
# 17509    295516                    iPhone                 1          700.00
# 17512    295519  Lightning Charging Cable                 1           14.95
# 17516    295523    AAA Batteries (4-pack)                 1            2.99
# 17585    295590     AA Batteries (4-pack)                 1            3.84
# 17591    295596          Wired Headphones                 1           11.99
#
#                      Date                         Purchase_Address Week Month  \
# 0     2019-01-22 21:25:00          944 Walnut St, Boston, MA 02215    4     1
# 1     2019-01-28 14:15:00         185 Maple St, Portland, OR 97035    5     1
# 2     2019-01-17 13:33:00    538 Adams St, San Francisco, CA 94016    3     1
# 3     2019-05-01 20:33:00       738 10th St, Los Angeles, CA 90001   18     5
# 4     2019-01-25 11:59:00            387 10th St, Austin, TX 73301    4     1
# ...                   ...                                      ...  ...   ...
# 17509 2019-11-19 23:16:00        603 4th St, Los Angeles, CA 90001   47    11
# 17512 2019-11-19 19:04:00   979 Wilson St, New York City, NY 10001   47    11
# 17516 2019-11-19 17:52:00      965 Elm St, San Francisco, CA 94016   47    11
# 17585 2019-11-19 09:41:00    772 South St, New York City, NY 10001   47    11
# 17591 2019-11-19 00:34:00  865 Lincoln St, San Francisco, CA 94016   47    11
#
#        Year  Total_Amount  Total_Amount ($)
# 0      2019        700.00            700.00
# 1      2019         14.95             14.95
# 2      2019         23.98             23.98
# 3      2019        149.99            149.99
# 4      2019         11.99             11.99
# ...     ...           ...               ...
# 17509  2019        700.00            700.00
# 17512  2019         14.95             14.95
# 17516  2019          2.99              2.99
# 17585  2019          3.84              3.84
# 17591  2019         11.99             11.99
#
# [88638 rows x 11 columns]

# %%
# Normalizing the date column to remove hour, seconds

data_2019['Date'] = pd.to_datetime(data_2019['Date']).dt.normalize()

data_2019
# Out:
#        Order_ID                   Product  Quantity_Ordered  Unit_Price ($)  \
# 0        141234                    iPhone                 1          700.00
# 1        141235  Lightning Charging Cable                 1           14.95
# 2        141236          Wired Headphones                 2           11.99
# 3        141237          27in FHD Monitor                 1          149.99
# 4        141238          Wired Headphones                 1           11.99
# ...         ...                       ...               ...             ...
# 17509    295516                    iPhone                 1          700.00
# 17512    295519  Lightning Charging Cable                 1           14.95
# 17516    295523    AAA Batteries (4-pack)                 1            2.99
# 17585    295590     AA Batteries (4-pack)                 1            3.84
# 17591    295596          Wired Headphones                 1           11.99
#
#             Date                         Purchase_Address Week Month  Year  \
# 0     2019-01-22          944 Walnut St, Boston, MA 02215    4     1  2019
# 1     2019-01-28         185 Maple St, Portland, OR 97035    5     1  2019
# 2     2019-01-17    538 Adams St, San Francisco, CA 94016    3     1  2019
# 3     2019-05-01       738 10th St, Los Angeles, CA 90001   18     5  2019
# 4     2019-01-25            387 10th St, Austin, TX 73301    4     1  2019
# ...          ...                                      ...  ...   ...   ...
# 17509 2019-11-19        603 4th St, Los Angeles, CA 90001   47    11  2019
# 17512 2019-11-19   979 Wilson St, New York City, NY 10001   47    11  2019
# 17516 2019-11-19      965 Elm St, San Francisco, CA 94016   47    11  2019
# 17585 2019-11-19    772 South St, New York City, NY 10001   47    11  2019
# 17591 2019-11-19  865 Lincoln St, San Francisco, CA 94016   47    11  2019
#
#        Total_Amount  Total_Amount ($)
# 0            700.00            700.00
# 1             14.95             14.95
# 2             23.98             23.98
# 3            149.99            149.99
# 4             11.99             11.99
# ...             ...               ...
# 17509        700.00            700.00
# 17512         14.95             14.95
# 17516          2.99              2.99
# 17585          3.84              3.84
# 17591         11.99             11.99
#
# [88638 rows x 11 columns]

# %%
# making date the index column

data_2019 = data_2019.set_index((data_2019.select_dtypes(include=[np.datetime64]).columns).tolist())

data_2019
# Out:
#             Order_ID                   Product  Quantity_Ordered  \
# Date
# 2019-01-22    141234                    iPhone                 1
# 2019-01-28    141235  Lightning Charging Cable                 1
# 2019-01-17    141236          Wired Headphones                 2
# 2019-05-01    141237          27in FHD Monitor                 1
# 2019-01-25    141238          Wired Headphones                 1
# ...              ...                       ...               ...
# 2019-11-19    295516                    iPhone                 1
# 2019-11-19    295519  Lightning Charging Cable                 1
# 2019-11-19    295523    AAA Batteries (4-pack)                 1
# 2019-11-19    295590     AA Batteries (4-pack)                 1
# 2019-11-19    295596          Wired Headphones                 1
#
#             Unit_Price ($)                         Purchase_Address Week  \
# Date
# 2019-01-22          700.00          944 Walnut St, Boston, MA 02215    4
# 2019-01-28           14.95         185 Maple St, Portland, OR 97035    5
# 2019-01-17           11.99    538 Adams St, San Francisco, CA 94016    3
# 2019-05-01          149.99       738 10th St, Los Angeles, CA 90001   18
# 2019-01-25           11.99            387 10th St, Austin, TX 73301    4
# ...                    ...                                      ...  ...
# 2019-11-19          700.00        603 4th St, Los Angeles, CA 90001   47
# 2019-11-19           14.95   979 Wilson St, New York City, NY 10001   47
# 2019-11-19            2.99      965 Elm St, San Francisco, CA 94016   47
# 2019-11-19            3.84    772 South St, New York City, NY 10001   47
# 2019-11-19           11.99  865 Lincoln St, San Francisco, CA 94016   47
#
#            Month  Year  Total_Amount  Total_Amount ($)
# Date
# 2019-01-22     1  2019        700.00            700.00
# 2019-01-28     1  2019         14.95             14.95
# 2019-01-17     1  2019         23.98             23.98
# 2019-05-01     5  2019        149.99            149.99
# 2019-01-25     1  2019         11.99             11.99
# ...          ...   ...           ...               ...
# 2019-11-19    11  2019        700.00            700.00
# 2019-11-19    11  2019         14.95             14.95
# 2019-11-19    11  2019          2.99              2.99
# 2019-11-19    11  2019          3.84              3.84
# 2019-11-19    11  2019         11.99             11.99
#
# [88638 rows x 10 columns]

# %%
# Saving the cleaned Dataset

data_2019.to_csv('data_2019.csv')

# %% [markdown]
# ## UNIVARIATE ANALYSIS
